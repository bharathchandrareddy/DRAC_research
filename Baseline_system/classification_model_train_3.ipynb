# %%
import numpy as np
import pandas as pd
import os
import math
import random
import json
import cv2

from PIL import Image
import time

import shapely.wkt
import shapely
from shapely.geometry import Polygon
from sklearn.model_selection import train_test_split

import tensorflow as tf
from sklearn.utils import class_weight
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import f1_score, accuracy_score
from tensorflow.keras import Sequential
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.applications.resnet50 import ResNet50
import tensorflow.keras.backend as K
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 15
#      13 import shapely
#      14 from shapely.geometry import Polygon
# ---> 15 from sklearn.model_selection import train_test_split
#      17 import tensorflow as tf
#      18 from sklearn.utils import class_weight
#
# File c:\Users\PC\anaconda3\envs\classification_model\lib\site-packages\sklearn\__init__.py:82
#      80 from . import _distributor_init  # noqa: F401
#      81 from . import __check_build  # noqa: F401
# ---> 82 from .base import clone
#      83 from .utils._show_versions import show_versions
#      85 __all__ = [
#      86     "calibration",
#      87     "cluster",
#    (...)
#     128     "show_versions",
#     129 ]
#
# File c:\Users\PC\anaconda3\envs\classification_model\lib\site-packages\sklearn\base.py:17
#      15 from . import __version__
#      16 from ._config import get_config
# ---> 17 from .utils import _IS_32BIT
#      18 from .utils._set_output import _SetOutputMixin
#      19 from .utils._tags import (
#      20     _DEFAULT_TAGS,
#      21 )
#
# File c:\Users\PC\anaconda3\envs\classification_model\lib\site-packages\sklearn\utils\__init__.py:25
#      23 from .deprecation import deprecated
#      24 from .discovery import all_estimators
# ---> 25 from .fixes import parse_version, threadpool_info
#      26 from ._estimator_html_repr import estimator_html_repr
#      27 from .validation import (
#      28     as_float_array,
#      29     assert_all_finite,
#    (...)
#      38     _is_arraylike_not_scalar,
#      39 )
#
# File c:\Users\PC\anaconda3\envs\classification_model\lib\site-packages\sklearn\utils\fixes.py:19
#      17 import numpy as np
#      18 import scipy
# ---> 19 import scipy.stats
#      20 import threadpoolctl
#      22 from .deprecation import deprecated
#
# File c:\Users\PC\anaconda3\envs\classification_model\lib\site-packages\scipy\stats\__init__.py:610
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)
#     605
#     606 """  # noqa: E501
#     608 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     609                                DegenerateDataWarning, FitError)
# --> 610 from ._stats_py import *
#     611 from ._variation import variation
#     612 from .distributions import *
#
# File c:\Users\PC\anaconda3\envs\classification_model\lib\site-packages\scipy\stats\_stats_py.py:38
#      35 from numpy import array, asarray, ma
#      37 from scipy import sparse
# ---> 38 from scipy.spatial import distance_matrix
#      40 from scipy.optimize import milp, LinearConstraint
#      41 from scipy._lib._util import (check_random_state, _get_nan,
#      42                               _rename_parameter, _contains_nan,
#      43                               AxisError)
#
# File c:\Users\PC\anaconda3\envs\classification_model\lib\site-packages\scipy\spatial\__init__.py:110
#       1 """
#       2 =============================================================
#       3 Spatial algorithms and data structures (:mod:`scipy.spatial`)
#    (...)
#     107    QhullError
#     108 """  # noqa: E501
# --> 110 from ._kdtree import *
#     111 from ._ckdtree import *
#     112 from ._qhull import *
#
# File c:\Users\PC\anaconda3\envs\classification_model\lib\site-packages\scipy\spatial\_kdtree.py:4
#       1 # Copyright Anne M. Archibald 2008
#       2 # Released under the scipy license
#       3 import numpy as np
# ----> 4 from ._ckdtree import cKDTree, cKDTreeNode
#       6 __all__ = ['minkowski_distance_p', 'minkowski_distance',
#       7            'distance_matrix',
#       8            'Rectangle', 'KDTree']
#      11 def minkowski_distance_p(x, y, p=2):
#
# File _ckdtree.pyx:12, in init scipy.spatial._ckdtree()
#
# ImportError: cannot import name copy_if_needed

# %%
# from google.colab import drive
# drive.mount('/content/drive')\
print(np.__version__)
print(pd.__version__)
# Out:
# 1.26.4
# 2.2.2

# %%
# Configure paths for classification model
#xbd_dir="/content/drive/MyDrive/XBD/test/"
xbd_dir="/Users/yugandarnarra/Downloads/Project/train"
images_dir = os.path.join(xbd_dir,"images")
labels_dir = os.path.join(xbd_dir,"labels")
classification_data = os.path.join(xbd_dir,"classification_data")
cropped_images=os.path.join(classification_data,"cropped_images")
model_save_path = os.path.join(xbd_dir,"models/")

train_csv = os.path.join(classification_data,"train.csv")
test_csv = os.path.join(classification_data,"test.csv")

os.makedirs(classification_data, exist_ok=True)
os.makedirs(cropped_images, exist_ok=True)
os.makedirs(model_save_path, exist_ok=True)

damage_labels = {0:"0", 1:"1", 2:"2", 3:"3"}
batch_size = 64
epochs = 100

# %%
#Crop the image to buildings
def crop_images_to_polygons(img_array, polygon_pts):
    height, width, channels = img_array.shape
    # get x and y coordinates from the polygon points
    x_coords,y_coords = polygon_pts[:, 0],polygon_pts[:, 1]
    # minimum and maximum x and y coordinates
    xmin, xmax = np.min(x_coords), np.max(x_coords)
    ymin, ymax = np.min(y_coords), np.max(y_coords)
    # differences between maximum and minimum coordinates
    xdiff, ydiff = xmax - xmin, ymax - ymin
    # extend image by 80% of the width and height
    xmin = max(int(xmin - (xdiff * 0.8)), 0)
    xmax = min(int(xmax + (xdiff * 0.8)), width)
    ymin = max(int(ymin - (ydiff * 0.8)), 0)
    ymax = min(int(ymax + (ydiff * 0.8)), height)
    # Crop the image using the co-ordinates
    return img_array[ymin:ymax, xmin:xmax, :]

# %%
def process_label_data(images_dir, output_path, output_csv_path):
    x_data = []
    y_data = []
    # Encode damage labels to integers
    damage_labels = { 'un-classified' : 0, 'no-damage': 0 , 'minor-damage': 1, 'major-damage': 2, 'destroyed': 3 }
    # Read Image and Label files and crop the buildings
    for image_name in os.listdir(images_dir):
        img_path = os.path.join(images_dir,image_name)
        img_obj = Image.open(img_path)
        img_array = np.array(img_obj)
        label_name = image_name.replace('.png', '.json')
        label_path = os.path.join(labels_dir,label_name)
        label_file = open(label_path)
        label_data = json.load(label_file)
        for feat in label_data['features']['xy']:
            # get the damage type and building id
            damage_type = feat['properties'].get('subtype', 'no-damage')
            poly_uid = feat['properties']['uid']
            poly_uid += ".png"
            # add the damage label to y_data
            y_data.append(damage_labels[damage_type])
            # extract building shape in wkt format from json and convert to shapely object
            building_shape = wkt.loads(feat['wkt'])
            # extract building vertices/co-ordinates from shapely object
            polygon_pts = np.array(list(building_shape.exterior.coords))
            poly_img = crop_images_to_polygons(img_array, polygon_pts)
            # save the cropped image with building_id
            cv2.imwrite(os.path.join(output_path,poly_uid), poly_img )
            # add building_id.png to x_data
            x_data.append(poly_uid)

    # Split the data into training and testing sets
    output_train_csv_path = os.path.join(output_csv_path, "train.csv")
    output_test_csv_path = os.path.join(output_csv_path, "test.csv")
    x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.25)
    data_array_train = {'building_id': x_train, 'damage_level': y_train}
    data_array_test = {'building_id': x_test, 'damage_level': y_test}
    # Save the train and test to CSV files
    df_train = pd.DataFrame(data_array_train)
    df_test = pd.DataFrame(data_array_test)
    df_train.to_csv(output_train_csv_path)
    df_test.to_csv(output_test_csv_path)

# %%
process_label_data(images_dir, cropped_images, classification_data)

# %%
# F1 Score
def f1(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    # Recall
    recall = true_positives / (possible_positives + K.epsilon())
    # Precision
    precision = true_positives / (predicted_positives + K.epsilon())
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
# VGG16 model
# def classification_model():
#     inputs = layers.Input(shape=(128, 128, 3))
#     base_model = VGG16(weights='imagenet', include_top=False, pooling='max', input_shape=(128, 128, 3))
#     for layer in base_model.layers:
#         layer.trainable = False
#     x = layers.Conv2D(32, (5, 5), strides=(1, 1), padding='same', activation='relu')(inputs)
#     x = layers.MaxPooling2D(pool_size=(2, 2), strides=None, padding='valid')(x)
#     x = layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation='relu')(x)
#     x = layers.MaxPooling2D(pool_size=(2, 2), strides=None, padding='valid')(x)
#     x = layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation='relu')(x)
#     x = layers.MaxPooling2D(pool_size=(2, 2), strides=None, padding='valid')(x)
#     x = layers.Flatten()(x)
#     base_resnet = base_model(inputs)
#     base_resnet = layers.Flatten()(base_resnet)
#     concatenated_layers = layers.Concatenate()([x, base_resnet])
#     x = layers.Dense(2024, activation='relu')(concatenated_layers)
#     x = layers.Dense(512, activation='relu')(x)
#     x = layers.Dense(128, activation='relu')(x)
#     output = layers.Dense(4, activation='softmax')(x)
#     model = Model(inputs=inputs, outputs=output)
#     return model

# %%
# Resnet18 model
# def classification_model():
#     inputs = layers.Input(shape=(128, 128, 3))
#     base_model = ResNet18(weights='imagenet', include_top=False, pooling='max', input_shape=(128, 128, 3))
#     for layer in base_model.layers:
#         layer.trainable = False
#     x = layers.Conv2D(32, (5, 5), strides=(1, 1), padding='same', activation='relu')(inputs)
#     x = layers.MaxPooling2D(pool_size=(2, 2), strides=None, padding='valid')(x)
#     x = layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation='relu')(x)
#     x = layers.MaxPooling2D(pool_size=(2, 2), strides=None, padding='valid')(x)
#     x = layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation='relu')(x)
#     x = layers.MaxPooling2D(pool_size=(2, 2), strides=None, padding='valid')(x)
#     x = layers.Flatten()(x)
#     base_resnet = base_model(inputs)
#     base_resnet = layers.Flatten()(base_resnet)
#     concatenated_layers = layers.Concatenate()([x, base_resnet])
#     x = layers.Dense(2048, activation='relu')(concatenated_layers)
#     x = layers.Dense(1024, activation='relu')(x)
#     x = layers.Dense(512, activation='relu')(x)
#     x = layers.Dense(256, activation='relu')(x)
#     x = layers.Dense(128, activation='relu')(x)
#     x = layers.Dense(32, activation='relu')(x)
#     output = layers.Dense(4, activation='softmax')(x)
#     model = Model(inputs=inputs, outputs=output)
#     return model


# def classification_model():
#     # input layer
#     input_layer = layers.Input(shape=(128, 128, 3))
#     # pre-trained ResNet50 as base model
#     resnet_model = ResNet50(include_top=False, weights='imagenet', input_shape=(128, 128, 3))
#     # freeze base model layers
#     for layer in resnet_model.layers:
#         layer.trainable = False
#     # input through ResNet model
#     base_resnet_model = resnet_model(input_layer)
#     # flatten output from the resnet model
#     base_resnet_model = layers.Flatten()(base_resnet_model)
#     # # conv2d and maxpool layers
#     x = layers.Conv2D(32, (5, 5), strides=(1, 1), padding='same', activation='relu')(input_layer)
#     x = layers.BatchNormalization()(x)
#     x = layers.MaxPooling2D(pool_size=(2, 2), strides=None, padding='valid')(x)
    
#     x = layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation='relu')(x)
#     x = layers.BatchNormalization()(x)
#     x = layers.MaxPooling2D(pool_size=(2, 2), strides=None, padding='valid')(x)
    
#     x = layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation='relu')(x)
#     x = layers.BatchNormalization()(x)
#     x = layers.MaxPooling2D(pool_size=(2, 2), strides=None, padding='valid')(x)
#     # flatten output from conv2d and maxpool layers
#     x = layers.Flatten()(x)
#     # concatenate outputs of convolutional layers and base ResNet model
#     concatenated_layers = layers.Concatenate()([x, base_resnet_model])
#     # Fully connected layers
#     x = layers.Dense(1024, activation='relu')(x)
#     x = layers.Dropout(0.3)(x) 
#     x = layers.Dense(512, activation='relu')(x)
#     x = layers.Dropout(0.4)(x)
#     x = layers.Dense(256, activation='relu')(x)
#     x = layers.Dropout(0.3)(x) 
#     x = layers.Dense(128, activation='relu')(x)
#     x = layers.Dropout(0.2)(x)
#     # output layer
#     output = layers.Dense(4, activation='softmax')(x)
#     # define model
#     model = Model(inputs=input_layer, outputs=output)
#     return model

# Define Classification Model
# def classification_model():
#     # input layer
#     input_layer = layers.Input(shape=(128, 128, 3))
#     # pre-trained ResNet50 as base model
#     resnet_model = ResNet50(include_top=False, weights='imagenet', input_shape=(128, 128, 3))
#     # freeze base model layers
#     for layer in resnet_model.layers:
#         layer.trainable = False
#     # input through ResNet model
#     base_resnet_model = resnet_model(input_layer)
#     # flatten output from the resnet model
#     base_resnet_model = layers.Flatten()(base_resnet_model)
#     # # conv2d and maxpool layers
#     x = layers.Conv2D(32, (5, 5), strides=(1, 1), padding='same', activation='relu')(input_layer)
#     x = layers.MaxPooling2D(pool_size=(2, 2), strides=None, padding='valid')(x)
#     x = layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation='relu')(x)
#     x = layers.MaxPooling2D(pool_size=(2, 2), strides=None, padding='valid')(x)
#     x = layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation='relu')(x)
#     x = layers.MaxPooling2D(pool_size=(2, 2), strides=None, padding='valid')(x)
#     # flatten output from conv2d and maxpool layers
#     x = layers.Flatten()(x)
#     # concatenate outputs of convolutional layers and base ResNet model
#     concatenated_layers = layers.Concatenate()([x, base_resnet_model])
#     # Fully connected layers
#     x = layers.Dense(2024, activation='relu')(concatenated_layers)
#     x = layers.Dense(524, activation='relu')(x)
#     x = layers.Dense(124, activation='relu')(x)
#     # output layer
#     output = layers.Dense(4, activation='softmax')(x)
#     # define model
#     model = Model(inputs=input_layer, outputs=output)
#     return model

# def classification_model():
#     # Define the input layer with shape (128, 128, 3)
#     inputs = layers.Input(shape=(128, 128, 3))
    
#     # ResNet50 model pre-trained on ImageNet without the top layer
#     base_model = ResNet50(include_top=False, weights='imagenet', input_shape=(128, 128, 3))
    
#     # Freeze the layers of the base model so they are not trainable
#     for layer in base_model.layers:
#         layer.trainable = False
    
#     # convolutional layer with 32 filters, 5x5 kernel size, and ReLU activation
#     x = layers.Conv2D(32, (5, 5), strides=(1, 1), padding='same', activation='relu')(inputs)
#     # average pooling layer with pool size (2, 2)
#     x = layers.AveragePooling2D(pool_size=(2, 2), strides=None, padding='valid')(x)
    
#     # convolutional layer with 64 filters, 3x3 kernel size, and ReLU activation
#     x = layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation='relu')(x)
#     # Add average pooling layer with pool size (2, 2)
#     x = layers.AveragePooling2D(pool_size=(2, 2), strides=None, padding='valid')(x)
    
#     # convolutional layer with 64 filters, 3x3 kernel size, and ReLU activation
#     x = layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation='relu')(x)
#     # pooling layer with pool size (2, 2)
#     x = layers.AveragePooling2D(pool_size=(2, 2), strides=None, padding='valid')(x)
    
#     # Flatten the output of the convolutional layers
#     x = layers.Flatten()(x)
    
#     # Pass the input through the base ResNet50 model and flatten its output
#     base_resnet = base_model(inputs)
#     base_resnet = layers.Flatten()(base_resnet)
    
#     # Concatenate the output of the convolutional layers and the output of the base ResNet50 model
#     concatenated_layers = layers.Concatenate()([x, base_resnet])
    
#     # fully connected layer with 2024 neurons and ReLU activation
#     x = layers.Dense(2024, activation='relu')(concatenated_layers)
#     # fully connected layer with 524 neurons and ReLU activation
#     x = layers.Dense(524, activation='relu')(x)
#     # dropout layer with dropout rate 0.4
#     x = layers.Dropout(0.4)(x)
#     # fully connected layer with 124 neurons and ReLU activation
#     x = layers.Dense(124, activation='relu')(x)
    
#     # Output layer with 4 neurons for classification and softmax activation
#     output = layers.Dense(4, activation='softmax')(x)
    
#     # model with input and output layers
#     model = Model(inputs=inputs, outputs=output)
    
#     return model

# %%
# Loss function for ordinal loss
def ordinal_loss(y_true, y_pred):
    weights = K.cast(K.abs(K.argmax(y_true, axis=1) - K.argmax(y_pred, axis=1))/(K.int_shape(y_pred)[1] - 1), dtype='float32')
    return (1.0 + weights) * keras.losses.categorical_crossentropy(y_true, y_pred )

def classification_model():
    # Define the input layer with shape (128, 128, 3)
    inputs = layers.Input(shape=(128, 128, 3))

    # ResNet50 model pre-trained on ImageNet without the top layer
    base_model = ResNet50(include_top=False, weights='imagenet', input_shape=(128, 128, 3))

    # Freeze the layers of the base model so they are not trainable
    for layer in base_model.layers:
        layer.trainable = False

    # convolutional layer with 32 filters, 5x5 kernel size, and ReLU activation
    x = layers.Conv2D(32, (5, 5), strides=(1, 1), padding='same', activation='relu')(inputs)
    # max pooling layer with pool size (2, 2)
    x = x = layers.MaxPooling2D(pool_size=(2, 2), strides=None, padding='valid')(x)

    # convolutional layer with 64 filters, 3x3 kernel size, and ReLU activation
    x = layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation='relu')(x)
    # max pooling layer with pool size (2, 2)
    x = layers.MaxPooling2D(pool_size=(2, 2), strides=None, padding='valid')(x)

    # convolutional layer with 64 filters, 3x3 kernel size, and ReLU activation
    x = layers.Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation='relu')(x)
    # pooling layer with pool size (2, 2)
    x = x = layers.MaxPooling2D(pool_size=(2, 2), strides=None, padding='valid')(x)

    # Flatten the output of the convolutional layers
    x = layers.Flatten()(x)

    # Pass the input through the base ResNet50 model and flatten its output
    base_resnet = base_model(inputs)
    base_resnet = layers.Flatten()(base_resnet)

    # Concatenate the output of the convolutional layers and the output of the base ResNet50 model
    concatenated_layers = layers.Concatenate()([x, base_resnet])

    # fully connected layer with 2024 neurons and ReLU activation
    x = layers.Dense(2024, activation='relu')(concatenated_layers)
    # fully connected layer with 524 neurons and ReLU activation
    x = layers.Dense(524, activation='relu')(x)
    # dropout layer with dropout rate 0.4
    x = layers.Dropout(0.4)(x)
    # fully connected layer with 124 neurons and ReLU activation
    x = layers.Dense(124, activation='relu')(x)
    # Output layer with 4 neurons for classification and softmax activation
    output = layers.Dense(4, activation='softmax')(x)

    # model with input and output layers
    model = Model(inputs=inputs, outputs=output)

    return model

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: DLL load failed while importing _multiarray_umath: The specified module could not be found.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: DLL load failed while importing _multiarray_umath: The specified module could not be found.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: DLL load failed while importing _multiarray_umath: The specified module could not be found.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: DLL load failed while importing _multiarray_umath: The specified module could not be found.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: DLL load failed while importing _multiarray_umath: The specified module could not be found.
# Num GPUs Available:  1

# %%
# Train and Validation dataset
df = pd.read_csv(train_csv)
label_classes = np.unique(df['damage_level'].to_list())
label_class_weights = class_weight.compute_class_weight(class_weight='balanced',classes= label_classes, y=df['damage_level'].to_list())
label_class_weights = dict(enumerate(label_class_weights))

num_cropped_images = df['building_id'].count()
steps = np.ceil(num_cropped_images/batch_size)

df = df.replace({"damage_level" : damage_labels})
train_gen = ImageDataGenerator(horizontal_flip=True,vertical_flip=True,rescale=1/255.)
train_dataset = train_gen.flow_from_dataframe(dataframe=df,directory=cropped_images, x_col='building_id',y_col='damage_level',batch_size=64,seed=123,class_mode="categorical",target_size=(128, 128))

df = pd.read_csv(test_csv)
df = df.replace({"damage_level" : damage_labels })
valid_gen = ImageDataGenerator(rescale=1/255.)
valid_dataset = valid_gen.flow_from_dataframe(dataframe=df,directory=cropped_images,x_col='building_id',y_col='damage_level',batch_size=64,shuffle=False,seed=123,class_mode="categorical",target_size=(128, 128))
# Out:
# Found 82293 validated image filenames belonging to 4 classes.
# Found 27431 validated image filenames belonging to 4 classes.

# %%
#Classification Model
model = classification_model()
#model.summary()

# %%
# Compile with Adam Optimizer
model.compile(loss=ordinal_loss, optimizer=keras.optimizers.Adam(learning_rate=0.0001), metrics=['accuracy', f1])

# %%
#Train the classification model
model.fit(train_dataset,steps_per_epoch=steps,epochs=epochs,workers=4,use_multiprocessing=True,class_weight=label_class_weights,verbose=1)

#Evaluate model using validation dataset
predictions = model.predict(valid_dataset)
val_trues = valid_dataset.classes
val_pred = np.argmax(predictions, axis=-1)

f1_weighted = f1_score(val_trues, val_pred, average='weighted')
accuracy_score = accuracy_score(val_trues, val_pred)
print(f"Accuracy: {accuracy_score}")
print(f"F1_score: {f1_weighted}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step
# Found 12318 validated image filenames belonging to 4 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/preprocessing/image.py:1137: UserWarning: Found 28828 invalid image filename(s) in x_col="uuid". These filename(s) will be ignored.
#   warnings.warn(
# WARNING:tensorflow:`batch_size` is no longer needed in the `TensorBoard` Callback and will be ignored in TensorFlow 2.0.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# <ipython-input-3-f381b2dc8dd2>:171: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(generator=train_gen_flow,
# Epoch 1/100
# 643/643 [==============================] - ETA: 0s - loss: 1.0616 - accuracy: 0.5013 - f1: 0.2995
# Epoch 1: saving model to /content/drive/MyDrive/XBD/models-saved-model-01-0.50.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 643/643 [==============================] - 1260s 2s/step - loss: 1.0616 - accuracy: 0.5013 - f1: 0.2995
# Epoch 2/100
# 643/643 [==============================] - ETA: 0s - loss: 0.8176 - accuracy: 0.7565 - f1: 0.6413
# Epoch 2: saving model to /content/drive/MyDrive/XBD/models-saved-model-02-0.76.hdf5
# 643/643 [==============================] - 300s 464ms/step - loss: 0.8176 - accuracy: 0.7565 - f1: 0.6413
# Epoch 3/100
# 643/643 [==============================] - ETA: 0s - loss: 0.7763 - accuracy: 0.7955 - f1: 0.7145
# Epoch 3: saving model to /content/drive/MyDrive/XBD/models-saved-model-03-0.80.hdf5
# 643/643 [==============================] - 303s 469ms/step - loss: 0.7763 - accuracy: 0.7955 - f1: 0.7145
# Epoch 4/100
# 643/643 [==============================] - ETA: 0s - loss: 0.7714 - accuracy: 0.7831 - f1: 0.7061
# Epoch 4: saving model to /content/drive/MyDrive/XBD/models-saved-model-04-0.78.hdf5
# 643/643 [==============================] - 294s 452ms/step - loss: 0.7714 - accuracy: 0.7831 - f1: 0.7061
# Epoch 5/100
# 643/643 [==============================] - ETA: 0s - loss: 0.7431 - accuracy: 0.7981 - f1: 0.7328
# Epoch 5: saving model to /content/drive/MyDrive/XBD/models-saved-model-05-0.80.hdf5
# 643/643 [==============================] - 291s 450ms/step - loss: 0.7431 - accuracy: 0.7981 - f1: 0.7328
# Epoch 6/100
# 643/643 [==============================] - ETA: 0s - loss: 0.7190 - accuracy: 0.7994 - f1: 0.7181
# Epoch 6: saving model to /content/drive/MyDrive/XBD/models-saved-model-06-0.80.hdf5
# 643/643 [==============================] - 290s 448ms/step - loss: 0.7190 - accuracy: 0.7994 - f1: 0.7181
# Epoch 7/100
# 643/643 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.8097 - f1: 0.7630
# Epoch 7: saving model to /content/drive/MyDrive/XBD/models-saved-model-07-0.81.hdf5
# 643/643 [==============================] - 296s 458ms/step - loss: 0.6927 - accuracy: 0.8097 - f1: 0.7630
# Epoch 8/100
# 643/643 [==============================] - ETA: 0s - loss: 0.6585 - accuracy: 0.8225 - f1: 0.7524
# Epoch 8: saving model to /content/drive/MyDrive/XBD/models-saved-model-08-0.82.hdf5
# 643/643 [==============================] - 292s 452ms/step - loss: 0.6585 - accuracy: 0.8225 - f1: 0.7524
# Epoch 9/100
# 643/643 [==============================] - ETA: 0s - loss: 0.6388 - accuracy: 0.8249 - f1: 0.7585
# Epoch 9: saving model to /content/drive/MyDrive/XBD/models-saved-model-09-0.82.hdf5
# 643/643 [==============================] - 288s 444ms/step - loss: 0.6388 - accuracy: 0.8249 - f1: 0.7585
# Epoch 10/100
# 643/643 [==============================] - ETA: 0s - loss: 0.6138 - accuracy: 0.8248 - f1: 0.7740
# Epoch 10: saving model to /content/drive/MyDrive/XBD/models-saved-model-10-0.82.hdf5
# 643/643 [==============================] - 285s 440ms/step - loss: 0.6138 - accuracy: 0.8248 - f1: 0.7740
# Epoch 11/100
# 643/643 [==============================] - ETA: 0s - loss: 0.6016 - accuracy: 0.8311 - f1: 0.7841
# Epoch 11: saving model to /content/drive/MyDrive/XBD/models-saved-model-11-0.83.hdf5
# 643/643 [==============================] - 302s 467ms/step - loss: 0.6016 - accuracy: 0.8311 - f1: 0.7841
# Epoch 12/100
# 643/643 [==============================] - ETA: 0s - loss: 0.5856 - accuracy: 0.8396 - f1: 0.7857
# Epoch 12: saving model to /content/drive/MyDrive/XBD/models-saved-model-12-0.84.hdf5
# 643/643 [==============================] - 290s 448ms/step - loss: 0.5856 - accuracy: 0.8396 - f1: 0.7857
# Epoch 13/100
# 643/643 [==============================] - ETA: 0s - loss: 0.5808 - accuracy: 0.8395 - f1: 0.7864
# Epoch 13: saving model to /content/drive/MyDrive/XBD/models-saved-model-13-0.84.hdf5
# 643/643 [==============================] - 294s 454ms/step - loss: 0.5808 - accuracy: 0.8395 - f1: 0.7864
# Epoch 14/100
# 643/643 [==============================] - ETA: 0s - loss: 0.5504 - accuracy: 0.8467 - f1: 0.8112
# Epoch 14: saving model to /content/drive/MyDrive/XBD/models-saved-model-14-0.85.hdf5
# 643/643 [==============================] - 302s 467ms/step - loss: 0.5504 - accuracy: 0.8467 - f1: 0.8112
# Epoch 15/100
# 643/643 [==============================] - ETA: 0s - loss: 0.5512 - accuracy: 0.8492 - f1: 0.8072
# Epoch 15: saving model to /content/drive/MyDrive/XBD/models-saved-model-15-0.85.hdf5
# 643/643 [==============================] - 299s 462ms/step - loss: 0.5512 - accuracy: 0.8492 - f1: 0.8072
# Epoch 16/100
# 643/643 [==============================] - ETA: 0s - loss: 0.5411 - accuracy: 0.8545 - f1: 0.8057
# Epoch 16: saving model to /content/drive/MyDrive/XBD/models-saved-model-16-0.85.hdf5
# 643/643 [==============================] - 298s 460ms/step - loss: 0.5411 - accuracy: 0.8545 - f1: 0.8057
# Epoch 17/100
# 643/643 [==============================] - ETA: 0s - loss: 0.5282 - accuracy: 0.8571 - f1: 0.8072
# Epoch 17: saving model to /content/drive/MyDrive/XBD/models-saved-model-17-0.86.hdf5
# 643/643 [==============================] - 296s 458ms/step - loss: 0.5282 - accuracy: 0.8571 - f1: 0.8072
# Epoch 18/100
# 643/643 [==============================] - ETA: 0s - loss: 0.5255 - accuracy: 0.8651 - f1: 0.8216
# Epoch 18: saving model to /content/drive/MyDrive/XBD/models-saved-model-18-0.87.hdf5
# 643/643 [==============================] - 289s 447ms/step - loss: 0.5255 - accuracy: 0.8651 - f1: 0.8216
# Epoch 19/100
# 643/643 [==============================] - ETA: 0s - loss: 0.5205 - accuracy: 0.8534 - f1: 0.8104
# Epoch 19: saving model to /content/drive/MyDrive/XBD/models-saved-model-19-0.85.hdf5
# 643/643 [==============================] - 289s 446ms/step - loss: 0.5205 - accuracy: 0.8534 - f1: 0.8104
# Epoch 20/100
# 643/643 [==============================] - ETA: 0s - loss: 0.5135 - accuracy: 0.8569 - f1: 0.8148
# Epoch 20: saving model to /content/drive/MyDrive/XBD/models-saved-model-20-0.86.hdf5
# 643/643 [==============================] - 293s 452ms/step - loss: 0.5135 - accuracy: 0.8569 - f1: 0.8148
# Epoch 21/100
# 643/643 [==============================] - ETA: 0s - loss: 0.5228 - accuracy: 0.8623 - f1: 0.8180
# Epoch 21: saving model to /content/drive/MyDrive/XBD/models-saved-model-21-0.86.hdf5
# 643/643 [==============================] - 288s 445ms/step - loss: 0.5228 - accuracy: 0.8623 - f1: 0.8180
# Epoch 22/100
# 643/643 [==============================] - ETA: 0s - loss: 0.4919 - accuracy: 0.8671 - f1: 0.8269
# Epoch 22: saving model to /content/drive/MyDrive/XBD/models-saved-model-22-0.87.hdf5
# 643/643 [==============================] - 300s 463ms/step - loss: 0.4919 - accuracy: 0.8671 - f1: 0.8269
# Epoch 23/100
# 643/643 [==============================] - ETA: 0s - loss: 0.4862 - accuracy: 0.8723 - f1: 0.8386
# Epoch 23: saving model to /content/drive/MyDrive/XBD/models-saved-model-23-0.87.hdf5
# 643/643 [==============================] - 291s 450ms/step - loss: 0.4862 - accuracy: 0.8723 - f1: 0.8386
# Epoch 24/100
# 643/643 [==============================] - ETA: 0s - loss: 0.4783 - accuracy: 0.8694 - f1: 0.8416
# Epoch 24: saving model to /content/drive/MyDrive/XBD/models-saved-model-24-0.87.hdf5
# 643/643 [==============================] - 316s 489ms/step - loss: 0.4783 - accuracy: 0.8694 - f1: 0.8416
# Epoch 25/100
# 643/643 [==============================] - ETA: 0s - loss: 0.4939 - accuracy: 0.8667 - f1: 0.8341
# Epoch 25: saving model to /content/drive/MyDrive/XBD/models-saved-model-25-0.87.hdf5
# 643/643 [==============================] - 309s 477ms/step - loss: 0.4939 - accuracy: 0.8667 - f1: 0.8341
# Epoch 26/100
# 643/643 [==============================] - ETA: 0s - loss: 0.4783 - accuracy: 0.8762 - f1: 0.8443
# Epoch 26: saving model to /content/drive/MyDrive/XBD/models-saved-model-26-0.88.hdf5
# 643/643 [==============================] - 309s 478ms/step - loss: 0.4783 - accuracy: 0.8762 - f1: 0.8443
# Epoch 27/100
# 643/643 [==============================] - ETA: 0s - loss: 0.4551 - accuracy: 0.8782 - f1: 0.8526
# Epoch 27: saving model to /content/drive/MyDrive/XBD/models-saved-model-27-0.88.hdf5
# 643/643 [==============================] - 297s 459ms/step - loss: 0.4551 - accuracy: 0.8782 - f1: 0.8526
# Epoch 28/100
# 643/643 [==============================] - ETA: 0s - loss: 0.4495 - accuracy: 0.8770 - f1: 0.8563
# Epoch 28: saving model to /content/drive/MyDrive/XBD/models-saved-model-28-0.88.hdf5
# 643/643 [==============================] - 297s 458ms/step - loss: 0.4495 - accuracy: 0.8770 - f1: 0.8563
# Epoch 29/100
# 643/643 [==============================] - ETA: 0s - loss: 0.4491 - accuracy: 0.8757 - f1: 0.8501
# Epoch 29: saving model to /content/drive/MyDrive/XBD/models-saved-model-29-0.88.hdf5
# 643/643 [==============================] - 301s 466ms/step - loss: 0.4491 - accuracy: 0.8757 - f1: 0.8501
# Epoch 30/100
# 643/643 [==============================] - ETA: 0s - loss: 0.4400 - accuracy: 0.8821 - f1: 0.8579
# Epoch 30: saving model to /content/drive/MyDrive/XBD/models-saved-model-30-0.88.hdf5
# 643/643 [==============================] - 295s 456ms/step - loss: 0.4400 - accuracy: 0.8821 - f1: 0.8579
# Epoch 31/100
# 643/643 [==============================] - ETA: 0s - loss: 0.5298 - accuracy: 0.8475 - f1: 0.8079
# Epoch 31: saving model to /content/drive/MyDrive/XBD/models-saved-model-31-0.85.hdf5
# 643/643 [==============================] - 301s 466ms/step - loss: 0.5298 - accuracy: 0.8475 - f1: 0.8079
# Epoch 32/100
# 643/643 [==============================] - ETA: 0s - loss: 0.4479 - accuracy: 0.8838 - f1: 0.8645
# Epoch 32: saving model to /content/drive/MyDrive/XBD/models-saved-model-32-0.88.hdf5
# 643/643 [==============================] - 293s 453ms/step - loss: 0.4479 - accuracy: 0.8838 - f1: 0.8645
# Epoch 33/100
# 643/643 [==============================] - ETA: 0s - loss: 0.4356 - accuracy: 0.8839 - f1: 0.8665
# Epoch 33: saving model to /content/drive/MyDrive/XBD/models-saved-model-33-0.88.hdf5
# 643/643 [==============================] - 298s 461ms/step - loss: 0.4356 - accuracy: 0.8839 - f1: 0.8665
# Epoch 34/100
# 643/643 [==============================] - ETA: 0s - loss: 0.4132 - accuracy: 0.8880 - f1: 0.8737
# Epoch 34: saving model to /content/drive/MyDrive/XBD/models-saved-model-34-0.89.hdf5
# 643/643 [==============================] - 294s 454ms/step - loss: 0.4132 - accuracy: 0.8880 - f1: 0.8737
# Epoch 35/100
# 643/643 [==============================] - ETA: 0s - loss: 0.4077 - accuracy: 0.8848 - f1: 0.8707
# Epoch 35: saving model to /content/drive/MyDrive/XBD/models-saved-model-35-0.88.hdf5
# 643/643 [==============================] - 288s 446ms/step - loss: 0.4077 - accuracy: 0.8848 - f1: 0.8707
# Epoch 36/100
# 643/643 [==============================] - ETA: 0s - loss: 0.4114 - accuracy: 0.8844 - f1: 0.8703
# Epoch 36: saving model to /content/drive/MyDrive/XBD/models-saved-model-36-0.88.hdf5
# 643/643 [==============================] - 313s 485ms/step - loss: 0.4114 - accuracy: 0.8844 - f1: 0.8703
# Epoch 37/100
# 643/643 [==============================] - ETA: 0s - loss: 0.4101 - accuracy: 0.8859 - f1: 0.8694
# Epoch 37: saving model to /content/drive/MyDrive/XBD/models-saved-model-37-0.89.hdf5
# 643/643 [==============================] - 290s 448ms/step - loss: 0.4101 - accuracy: 0.8859 - f1: 0.8694
# Epoch 38/100
# 643/643 [==============================] - ETA: 0s - loss: 0.4031 - accuracy: 0.8891 - f1: 0.8759
# Epoch 38: saving model to /content/drive/MyDrive/XBD/models-saved-model-38-0.89.hdf5
# 643/643 [==============================] - 300s 463ms/step - loss: 0.4031 - accuracy: 0.8891 - f1: 0.8759
# Epoch 39/100
# 643/643 [==============================] - ETA: 0s - loss: 0.4031 - accuracy: 0.8847 - f1: 0.8732
# Epoch 39: saving model to /content/drive/MyDrive/XBD/models-saved-model-39-0.88.hdf5
# 643/643 [==============================] - 293s 454ms/step - loss: 0.4031 - accuracy: 0.8847 - f1: 0.8732
# Epoch 40/100
# 643/643 [==============================] - ETA: 0s - loss: 0.4998 - accuracy: 0.8720 - f1: 0.8409
# Epoch 40: saving model to /content/drive/MyDrive/XBD/models-saved-model-40-0.87.hdf5
# 643/643 [==============================] - 296s 459ms/step - loss: 0.4998 - accuracy: 0.8720 - f1: 0.8409
# Epoch 41/100
# 643/643 [==============================] - ETA: 0s - loss: 0.4149 - accuracy: 0.8879 - f1: 0.8706
# Epoch 41: saving model to /content/drive/MyDrive/XBD/models-saved-model-41-0.89.hdf5
# 643/643 [==============================] - 299s 461ms/step - loss: 0.4149 - accuracy: 0.8879 - f1: 0.8706
# Epoch 42/100
# 643/643 [==============================] - ETA: 0s - loss: 0.4078 - accuracy: 0.8887 - f1: 0.8766
# Epoch 42: saving model to /content/drive/MyDrive/XBD/models-saved-model-42-0.89.hdf5
# 643/643 [==============================] - 294s 454ms/step - loss: 0.4078 - accuracy: 0.8887 - f1: 0.8766
# Epoch 43/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3865 - accuracy: 0.8953 - f1: 0.8817
# Epoch 43: saving model to /content/drive/MyDrive/XBD/models-saved-model-43-0.90.hdf5
# 643/643 [==============================] - 302s 468ms/step - loss: 0.3865 - accuracy: 0.8953 - f1: 0.8817
# Epoch 44/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3934 - accuracy: 0.8888 - f1: 0.8722
# Epoch 44: saving model to /content/drive/MyDrive/XBD/models-saved-model-44-0.89.hdf5
# 643/643 [==============================] - 298s 461ms/step - loss: 0.3934 - accuracy: 0.8888 - f1: 0.8722
# Epoch 45/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3711 - accuracy: 0.8924 - f1: 0.8825
# Epoch 45: saving model to /content/drive/MyDrive/XBD/models-saved-model-45-0.89.hdf5
# 643/643 [==============================] - 296s 457ms/step - loss: 0.3711 - accuracy: 0.8924 - f1: 0.8825
# Epoch 46/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3854 - accuracy: 0.8914 - f1: 0.8773
# Epoch 46: saving model to /content/drive/MyDrive/XBD/models-saved-model-46-0.89.hdf5
# 643/643 [==============================] - 299s 462ms/step - loss: 0.3854 - accuracy: 0.8914 - f1: 0.8773
# Epoch 47/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3630 - accuracy: 0.8925 - f1: 0.8850
# Epoch 47: saving model to /content/drive/MyDrive/XBD/models-saved-model-47-0.89.hdf5
# 643/643 [==============================] - 290s 448ms/step - loss: 0.3630 - accuracy: 0.8925 - f1: 0.8850
# Epoch 48/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3754 - accuracy: 0.8906 - f1: 0.8785
# Epoch 48: saving model to /content/drive/MyDrive/XBD/models-saved-model-48-0.89.hdf5
# 643/643 [==============================] - 292s 451ms/step - loss: 0.3754 - accuracy: 0.8906 - f1: 0.8785
# Epoch 49/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3581 - accuracy: 0.8888 - f1: 0.8789
# Epoch 49: saving model to /content/drive/MyDrive/XBD/models-saved-model-49-0.89.hdf5
# 643/643 [==============================] - 296s 458ms/step - loss: 0.3581 - accuracy: 0.8888 - f1: 0.8789
# Epoch 50/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3682 - accuracy: 0.8937 - f1: 0.8819
# Epoch 50: saving model to /content/drive/MyDrive/XBD/models-saved-model-50-0.89.hdf5
# 643/643 [==============================] - 288s 445ms/step - loss: 0.3682 - accuracy: 0.8937 - f1: 0.8819
# Epoch 51/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3512 - accuracy: 0.8896 - f1: 0.8820
# Epoch 51: saving model to /content/drive/MyDrive/XBD/models-saved-model-51-0.89.hdf5
# 643/643 [==============================] - 284s 439ms/step - loss: 0.3512 - accuracy: 0.8896 - f1: 0.8820
# Epoch 52/100
# 643/643 [==============================] - ETA: 0s - loss: 0.4601 - accuracy: 0.8725 - f1: 0.8367
# Epoch 52: saving model to /content/drive/MyDrive/XBD/models-saved-model-52-0.87.hdf5
# 643/643 [==============================] - 296s 458ms/step - loss: 0.4601 - accuracy: 0.8725 - f1: 0.8367
# Epoch 53/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3468 - accuracy: 0.8958 - f1: 0.8872
# Epoch 53: saving model to /content/drive/MyDrive/XBD/models-saved-model-53-0.90.hdf5
# 643/643 [==============================] - 295s 456ms/step - loss: 0.3468 - accuracy: 0.8958 - f1: 0.8872
# Epoch 54/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3459 - accuracy: 0.8911 - f1: 0.8824
# Epoch 54: saving model to /content/drive/MyDrive/XBD/models-saved-model-54-0.89.hdf5
# 643/643 [==============================] - 302s 468ms/step - loss: 0.3459 - accuracy: 0.8911 - f1: 0.8824
# Epoch 55/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3496 - accuracy: 0.9012 - f1: 0.8912
# Epoch 55: saving model to /content/drive/MyDrive/XBD/models-saved-model-55-0.90.hdf5
# 643/643 [==============================] - 311s 481ms/step - loss: 0.3496 - accuracy: 0.9012 - f1: 0.8912
# Epoch 56/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3521 - accuracy: 0.9001 - f1: 0.8920
# Epoch 56: saving model to /content/drive/MyDrive/XBD/models-saved-model-56-0.90.hdf5
# 643/643 [==============================] - 317s 489ms/step - loss: 0.3521 - accuracy: 0.9001 - f1: 0.8920
# Epoch 57/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3473 - accuracy: 0.8966 - f1: 0.8892
# Epoch 57: saving model to /content/drive/MyDrive/XBD/models-saved-model-57-0.90.hdf5
# 643/643 [==============================] - 321s 495ms/step - loss: 0.3473 - accuracy: 0.8966 - f1: 0.8892
# Epoch 58/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3469 - accuracy: 0.8953 - f1: 0.8859
# Epoch 58: saving model to /content/drive/MyDrive/XBD/models-saved-model-58-0.90.hdf5
# 643/643 [==============================] - 321s 497ms/step - loss: 0.3469 - accuracy: 0.8953 - f1: 0.8859
# Epoch 59/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3408 - accuracy: 0.9002 - f1: 0.8943
# Epoch 59: saving model to /content/drive/MyDrive/XBD/models-saved-model-59-0.90.hdf5
# 643/643 [==============================] - 345s 534ms/step - loss: 0.3408 - accuracy: 0.9002 - f1: 0.8943
# Epoch 60/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3249 - accuracy: 0.9041 - f1: 0.8999
# Epoch 60: saving model to /content/drive/MyDrive/XBD/models-saved-model-60-0.90.hdf5
# 643/643 [==============================] - 312s 481ms/step - loss: 0.3249 - accuracy: 0.9041 - f1: 0.8999
# Epoch 61/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3142 - accuracy: 0.9068 - f1: 0.9020
# Epoch 61: saving model to /content/drive/MyDrive/XBD/models-saved-model-61-0.91.hdf5
# 643/643 [==============================] - 309s 478ms/step - loss: 0.3142 - accuracy: 0.9068 - f1: 0.9020
# Epoch 62/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3111 - accuracy: 0.9025 - f1: 0.8983
# Epoch 62: saving model to /content/drive/MyDrive/XBD/models-saved-model-62-0.90.hdf5
# 643/643 [==============================] - 313s 485ms/step - loss: 0.3111 - accuracy: 0.9025 - f1: 0.8983
# Epoch 63/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3289 - accuracy: 0.9003 - f1: 0.8944
# Epoch 63: saving model to /content/drive/MyDrive/XBD/models-saved-model-63-0.90.hdf5
# 643/643 [==============================] - 318s 491ms/step - loss: 0.3289 - accuracy: 0.9003 - f1: 0.8944
# Epoch 64/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3298 - accuracy: 0.8944 - f1: 0.8880
# Epoch 64: saving model to /content/drive/MyDrive/XBD/models-saved-model-64-0.89.hdf5
# 643/643 [==============================] - 297s 459ms/step - loss: 0.3298 - accuracy: 0.8944 - f1: 0.8880
# Epoch 65/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3018 - accuracy: 0.9023 - f1: 0.8987
# Epoch 65: saving model to /content/drive/MyDrive/XBD/models-saved-model-65-0.90.hdf5
# 643/643 [==============================] - 299s 460ms/step - loss: 0.3018 - accuracy: 0.9023 - f1: 0.8987
# Epoch 66/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3393 - accuracy: 0.8961 - f1: 0.8879
# Epoch 66: saving model to /content/drive/MyDrive/XBD/models-saved-model-66-0.90.hdf5
# 643/643 [==============================] - 298s 461ms/step - loss: 0.3393 - accuracy: 0.8961 - f1: 0.8879
# Epoch 67/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3199 - accuracy: 0.8987 - f1: 0.8919
# Epoch 67: saving model to /content/drive/MyDrive/XBD/models-saved-model-67-0.90.hdf5
# 643/643 [==============================] - 292s 451ms/step - loss: 0.3199 - accuracy: 0.8987 - f1: 0.8919
# Epoch 68/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3621 - accuracy: 0.8982 - f1: 0.8866
# Epoch 68: saving model to /content/drive/MyDrive/XBD/models-saved-model-68-0.90.hdf5
# 643/643 [==============================] - 300s 464ms/step - loss: 0.3621 - accuracy: 0.8982 - f1: 0.8866
# Epoch 69/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3247 - accuracy: 0.8999 - f1: 0.8947
# Epoch 69: saving model to /content/drive/MyDrive/XBD/models-saved-model-69-0.90.hdf5
# 643/643 [==============================] - 293s 453ms/step - loss: 0.3247 - accuracy: 0.8999 - f1: 0.8947
# Epoch 70/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3019 - accuracy: 0.9058 - f1: 0.9006
# Epoch 70: saving model to /content/drive/MyDrive/XBD/models-saved-model-70-0.91.hdf5
# 643/643 [==============================] - 291s 450ms/step - loss: 0.3019 - accuracy: 0.9058 - f1: 0.9006
# Epoch 71/100
# 643/643 [==============================] - ETA: 0s - loss: 0.4414 - accuracy: 0.8680 - f1: 0.8455
# Epoch 71: saving model to /content/drive/MyDrive/XBD/models-saved-model-71-0.87.hdf5
# 643/643 [==============================] - 293s 453ms/step - loss: 0.4414 - accuracy: 0.8680 - f1: 0.8455
# Epoch 72/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3392 - accuracy: 0.8974 - f1: 0.8905
# Epoch 72: saving model to /content/drive/MyDrive/XBD/models-saved-model-72-0.90.hdf5
# 643/643 [==============================] - 291s 450ms/step - loss: 0.3392 - accuracy: 0.8974 - f1: 0.8905
# Epoch 73/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3069 - accuracy: 0.9096 - f1: 0.9063
# Epoch 73: saving model to /content/drive/MyDrive/XBD/models-saved-model-73-0.91.hdf5
# 643/643 [==============================] - 294s 453ms/step - loss: 0.3069 - accuracy: 0.9096 - f1: 0.9063
# Epoch 74/100
# 643/643 [==============================] - ETA: 0s - loss: 0.2942 - accuracy: 0.9116 - f1: 0.9080
# Epoch 74: saving model to /content/drive/MyDrive/XBD/models-saved-model-74-0.91.hdf5
# 643/643 [==============================] - 294s 455ms/step - loss: 0.2942 - accuracy: 0.9116 - f1: 0.9080
# Epoch 75/100
# 643/643 [==============================] - ETA: 0s - loss: 0.4615 - accuracy: 0.8632 - f1: 0.8455
# Epoch 75: saving model to /content/drive/MyDrive/XBD/models-saved-model-75-0.86.hdf5
# 643/643 [==============================] - 302s 467ms/step - loss: 0.4615 - accuracy: 0.8632 - f1: 0.8455
# Epoch 76/100
# 643/643 [==============================] - ETA: 0s - loss: 0.2843 - accuracy: 0.9118 - f1: 0.9086
# Epoch 76: saving model to /content/drive/MyDrive/XBD/models-saved-model-76-0.91.hdf5
# 643/643 [==============================] - 302s 467ms/step - loss: 0.2843 - accuracy: 0.9118 - f1: 0.9086
# Epoch 77/100
# 643/643 [==============================] - ETA: 0s - loss: 0.2848 - accuracy: 0.9113 - f1: 0.9078
# Epoch 77: saving model to /content/drive/MyDrive/XBD/models-saved-model-77-0.91.hdf5
# 643/643 [==============================] - 305s 471ms/step - loss: 0.2848 - accuracy: 0.9113 - f1: 0.9078
# Epoch 78/100
# 643/643 [==============================] - ETA: 0s - loss: 0.2962 - accuracy: 0.9074 - f1: 0.9045
# Epoch 78: saving model to /content/drive/MyDrive/XBD/models-saved-model-78-0.91.hdf5
# 643/643 [==============================] - 291s 449ms/step - loss: 0.2962 - accuracy: 0.9074 - f1: 0.9045
# Epoch 79/100
# 643/643 [==============================] - ETA: 0s - loss: 0.2865 - accuracy: 0.9093 - f1: 0.9066
# Epoch 79: saving model to /content/drive/MyDrive/XBD/models-saved-model-79-0.91.hdf5
# 643/643 [==============================] - 285s 438ms/step - loss: 0.2865 - accuracy: 0.9093 - f1: 0.9066
# Epoch 80/100
# 643/643 [==============================] - ETA: 0s - loss: 0.2844 - accuracy: 0.9053 - f1: 0.9013
# Epoch 80: saving model to /content/drive/MyDrive/XBD/models-saved-model-80-0.91.hdf5
# 643/643 [==============================] - 294s 456ms/step - loss: 0.2844 - accuracy: 0.9053 - f1: 0.9013
# Epoch 81/100
# 643/643 [==============================] - ETA: 0s - loss: 0.2864 - accuracy: 0.9085 - f1: 0.9055
# Epoch 81: saving model to /content/drive/MyDrive/XBD/models-saved-model-81-0.91.hdf5
# 643/643 [==============================] - 305s 470ms/step - loss: 0.2864 - accuracy: 0.9085 - f1: 0.9055
# Epoch 82/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3869 - accuracy: 0.8991 - f1: 0.8844
# Epoch 82: saving model to /content/drive/MyDrive/XBD/models-saved-model-82-0.90.hdf5
# 643/643 [==============================] - 290s 448ms/step - loss: 0.3869 - accuracy: 0.8991 - f1: 0.8844
# Epoch 83/100
# 643/643 [==============================] - ETA: 0s - loss: 0.2927 - accuracy: 0.9077 - f1: 0.9044
# Epoch 83: saving model to /content/drive/MyDrive/XBD/models-saved-model-83-0.91.hdf5
# 643/643 [==============================] - 297s 460ms/step - loss: 0.2927 - accuracy: 0.9077 - f1: 0.9044
# Epoch 84/100
# 643/643 [==============================] - ETA: 0s - loss: 0.2858 - accuracy: 0.9066 - f1: 0.9031
# Epoch 84: saving model to /content/drive/MyDrive/XBD/models-saved-model-84-0.91.hdf5
# 643/643 [==============================] - 300s 463ms/step - loss: 0.2858 - accuracy: 0.9066 - f1: 0.9031
# Epoch 85/100
# 643/643 [==============================] - ETA: 0s - loss: 0.2725 - accuracy: 0.9059 - f1: 0.9022
# Epoch 85: saving model to /content/drive/MyDrive/XBD/models-saved-model-85-0.91.hdf5
# 643/643 [==============================] - 317s 489ms/step - loss: 0.2725 - accuracy: 0.9059 - f1: 0.9022
# Epoch 86/100
# 643/643 [==============================] - ETA: 0s - loss: 0.5753 - accuracy: 0.8570 - f1: 0.8232
# Epoch 86: saving model to /content/drive/MyDrive/XBD/models-saved-model-86-0.86.hdf5
# 643/643 [==============================] - 297s 460ms/step - loss: 0.5753 - accuracy: 0.8570 - f1: 0.8232
# Epoch 87/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3124 - accuracy: 0.9061 - f1: 0.9022
# Epoch 87: saving model to /content/drive/MyDrive/XBD/models-saved-model-87-0.91.hdf5
# 643/643 [==============================] - 287s 445ms/step - loss: 0.3124 - accuracy: 0.9061 - f1: 0.9022
# Epoch 88/100
# 643/643 [==============================] - ETA: 0s - loss: 0.2793 - accuracy: 0.9120 - f1: 0.9085
# Epoch 88: saving model to /content/drive/MyDrive/XBD/models-saved-model-88-0.91.hdf5
# 643/643 [==============================] - 289s 447ms/step - loss: 0.2793 - accuracy: 0.9120 - f1: 0.9085
# Epoch 89/100
# 643/643 [==============================] - ETA: 0s - loss: 0.2704 - accuracy: 0.9076 - f1: 0.9039
# Epoch 89: saving model to /content/drive/MyDrive/XBD/models-saved-model-89-0.91.hdf5
# 643/643 [==============================] - 300s 464ms/step - loss: 0.2704 - accuracy: 0.9076 - f1: 0.9039
# Epoch 90/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3053 - accuracy: 0.9039 - f1: 0.8976
# Epoch 90: saving model to /content/drive/MyDrive/XBD/models-saved-model-90-0.90.hdf5
# 643/643 [==============================] - 296s 457ms/step - loss: 0.3053 - accuracy: 0.9039 - f1: 0.8976
# Epoch 91/100
# 643/643 [==============================] - ETA: 0s - loss: 0.2668 - accuracy: 0.9093 - f1: 0.9053
# Epoch 91: saving model to /content/drive/MyDrive/XBD/models-saved-model-91-0.91.hdf5
# 643/643 [==============================] - 319s 493ms/step - loss: 0.2668 - accuracy: 0.9093 - f1: 0.9053
# Epoch 92/100
# 643/643 [==============================] - ETA: 0s - loss: 0.2639 - accuracy: 0.9116 - f1: 0.9070
# Epoch 92: saving model to /content/drive/MyDrive/XBD/models-saved-model-92-0.91.hdf5
# 643/643 [==============================] - 315s 488ms/step - loss: 0.2639 - accuracy: 0.9116 - f1: 0.9070
# Epoch 93/100
# 643/643 [==============================] - ETA: 0s - loss: 0.2707 - accuracy: 0.9085 - f1: 0.9043
# Epoch 93: saving model to /content/drive/MyDrive/XBD/models-saved-model-93-0.91.hdf5
# 643/643 [==============================] - 321s 496ms/step - loss: 0.2707 - accuracy: 0.9085 - f1: 0.9043
# Epoch 94/100
# 643/643 [==============================] - ETA: 0s - loss: 0.3100 - accuracy: 0.9009 - f1: 0.8947
# Epoch 94: saving model to /content/drive/MyDrive/XBD/models-saved-model-94-0.90.hdf5
# 643/643 [==============================] - 310s 479ms/step - loss: 0.3100 - accuracy: 0.9009 - f1: 0.8947
# Epoch 95/100
# 643/643 [==============================] - ETA: 0s - loss: 0.2623 - accuracy: 0.9116 - f1: 0.9079
# Epoch 95: saving model to /content/drive/MyDrive/XBD/models-saved-model-95-0.91.hdf5
# 643/643 [==============================] - 301s 465ms/step - loss: 0.2623 - accuracy: 0.9116 - f1: 0.9079
# Epoch 96/100
# 643/643 [==============================] - ETA: 0s - loss: 0.2572 - accuracy: 0.9085 - f1: 0.9044
# Epoch 96: saving model to /content/drive/MyDrive/XBD/models-saved-model-96-0.91.hdf5
# 643/643 [==============================] - 313s 485ms/step - loss: 0.2572 - accuracy: 0.9085 - f1: 0.9044
# Epoch 97/100
# 643/643 [==============================] - ETA: 0s - loss: 0.2887 - accuracy: 0.9001 - f1: 0.8948
# Epoch 97: saving model to /content/drive/MyDrive/XBD/models-saved-model-97-0.90.hdf5
# 643/643 [==============================] - 320s 494ms/step - loss: 0.2887 - accuracy: 0.9001 - f1: 0.8948
# Epoch 98/100
# 643/643 [==============================] - ETA: 0s - loss: 0.2546 - accuracy: 0.9144 - f1: 0.9115
# Epoch 98: saving model to /content/drive/MyDrive/XBD/models-saved-model-98-0.91.hdf5
# 643/643 [==============================] - 318s 491ms/step - loss: 0.2546 - accuracy: 0.9144 - f1: 0.9115
# Epoch 99/100
# 643/643 [==============================] - ETA: 0s - loss: 0.2667 - accuracy: 0.9065 - f1: 0.9040
# Epoch 99: saving model to /content/drive/MyDrive/XBD/models-saved-model-99-0.91.hdf5
# 643/643 [==============================] - 315s 487ms/step - loss: 0.2667 - accuracy: 0.9065 - f1: 0.9040
# Epoch 100/100
# 643/643 [==============================] - ETA: 0s - loss: 0.2554 - accuracy: 0.9142 - f1: 0.9108
# Epoch 100: saving model to /content/drive/MyDrive/XBD/models-saved-model-100-0.91.hdf5
# 643/643 [==============================] - 311s 480ms/step - loss: 0.2554 - accuracy: 0.9142 - f1: 0.9108
# Found 4027 validated image filenames belonging to 4 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/preprocessing/image.py:1137: UserWarning: Found 9689 invalid image filename(s) in x_col="uuid". These filename(s) will be ignored.
#   warnings.warn(
# 63/63 [==============================] - 1688s 27s/step
# 0.922398930024723

# %%
#Save model weights
model.save_weights(model_save_path)
